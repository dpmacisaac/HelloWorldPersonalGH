# %% [markdown]
# # Data Visualization
# EDA: exploratory data analysis
# 1. Compute summary stats
# 1. Generate data visualizations
#
#
# ## Goals of Data Vis
# 1. Clearly and accurately represent data
# 1. Be creative, with the goal of increading readability
# 1. Label units, axes, and points of interests
#
# ## Some Jargon
# Chart: 2D visualization
# * Plot: a chart of data points (e.g. scatter plot)
# * Graph: a chart of a mathematical function (e.g. sine curve)
#
# ## Ways to use Matplotlib
# 1. Use the pyplot module: like a state machine (e.g. there is always a "current figure")
# 1. Use the OOP interface: maintain object references
# 1. Mix of the two
#
# # Matplotlib Chart Examples
# ## Line Chart Example

# %%
import matplotlib.pyplot as plt 

def line_chart_example(x, y, y3):
    plt.figure() # create a new "current figure"
    plt.plot(x, y, label="$y=x^2$")
    # plt.figure()
    plt.plot(x, y3, c="green", lw=5, label="$y=x^3$")
    # add some labels
    plt.legend()
    plt.title("Our First Line Chart")
    plt.xlabel("X Units")
    plt.ylabel("Y Units")
    plt.grid(True)
    # customize the x tick locations and labels
    xtick_labels = ["zero", "one", "two", "three super long label to overlap", "four"]
    plt.xticks(x, xtick_labels, rotation=15, ha="right")
    plt.show()

# we need some data
x = list(range(5))
y2 = [val ** 2 for val in x]
# task: add another to the figure for y = x^3
y3 = [val ** 3 for val in x]
line_chart_example(x, y2, y3)

# %% [markdown]
# ## Scatter Charts
# Plus saving a chart to a file (e.g. PDF, PNG, etc.)

# %%
import numpy as np

def scatter_chart_example(x, y):
    plt.figure() # make a new current figure
    plt.scatter(x, y, marker="x", s=100, c="purple")

    # you can save a figure to a file
    plt.tight_layout() # nice function to call right before rendering
    plt.savefig("scatter_chart.pdf")
    plt.show()
    
# we need data    
x = list(range(50))
y = [np.random.normal(100, 10) + value for value in x]
scatter_chart_example(x, y)

# %% [markdown]
# ## Bar Charts

# %%
def bar_chart_example(x, y):
    plt.figure()
    plt.bar(x, y)
    plt.show()
    
# back to y=x^2
x = list(range(5))
y = [value ** 2 for value in x]
bar_chart_example(x, y)

# %% [markdown]
# ## Pie Charts

# %%
def pie_chart_example(x, y):
    plt.figure()
    plt.pie(y, labels=x, autopct="%1.1f%%")
    plt.show()
    
pie_chart_example(x, y)

# %% [markdown]
# ## Histograms

# %%
def histogram_example(data):
    # data is a 1D list of data values
    plt.figure()
    plt.hist(data, bins=10) # default is 10
    plt.show()
    
# let's generate some random "normal" data
import numpy as np 
mean = 100 # mu
stdev = 10 # sigma 
num_samples = 1000 
normal_data = np.random.normal(mean, stdev, num_samples)
histogram_example(normal_data)

# %% [markdown]
# ## Box Plots

# %%
def box_plot_example(distributions): # distributions and labels are parallel
    # distributions: list of 1D lists of values
    plt.figure()
    plt.boxplot(distributions)
    # boxes correspond to the 1st and 3rd quartiles
    # line in the middle of the box corresponds to the 2nd quartile (AKA median)
    # whiskers corresponds to +/- 1.5 * IQR
    # IQR: interquartile range (3rd quartile - 1st quartile)
    # circles outside the whiskers correspond to outliers
    
    # annotations
    # we want to add "mu=100" to the center of our figure
    # xycoords="data": default, specify the location of the label in the same
    # xycoords = "axes fraction": specify the location of the label in absolute
    # axes coordinates... 0,0 is the lower left corner, 1,1 is the upper right corner
    # coordinates as the plotted data
    plt.annotate("$\mu=100$", xy=(1.5, 105), xycoords="data", horizontalalignment="center")
    plt.annotate("$\mu=100$", xy=(0.5, 0.5), xycoords="axes fraction", 
                 horizontalalignment="center", color="blue")

    plt.show()
    
normal_data2 = np.random.normal(mean, stdev / 2, num_samples)
box_plot_example([normal_data, normal_data2])

# %% [markdown]
# # Warm up Tasks
# 1. Create a bar and a pie chart for the model year counts we computed with `get_frequencies()`
# 1. Add another histogram with mean=100, stdev=5 to the same histogram figure
#     1. New histogram narrower or wider than the original (blue)?
# 1. Add a parameter to `box_plot_example()` called `labels`
#     1. `labels` is a 1D list of x-axis labels. Replace the 1 and 2 on the x axis `labels`
#     1. Call `box_plot_example()` passing in descriptions for the 2 distributions

# %%
import utils

def create_bar_graph(x,y):
    plt.figure()
    plt.bar(x, y)
    plt.show()

def create_pie(x,y):
    plt.figure()
    plt.pie(y, labels=x, autopct="%1.1f%%")
    plt.show()
    

header = ["CarName", "ModelYear", "MSRP"]
msrp_table = [["ford pinto", 75, 2769],
              ["toyota corolla", 75, 2711],
              ["ford pinto", 76, 3025],
              ["toyota corolla", 77, 2789],
              ["toyota corolla", 79, 3453],
              ["toyota highlander", 77, 2789],
              ["toyota toy", 78, 13]
              
              ]
val,count = utils.get_frequencies(msrp_table,header, "ModelYear")
create_bar_graph(val,count)
create_pie(val, count)

# %%
import utils
import importlib
importlib.reload(utils)
modelyears_names, modelyear_subtables = utils.group_by(msrp_table, header, "ModelYear")
print(modelyears_names)
print(modelyear_subtables)


#extract msrps from each subtable
msrp_distrs = [utils.get_column(subtable, header, "MSRP") for subtable in modelyear_subtables]
 
box_plot_example(msrp_distrs)
# Out:
# [75, 76, 77, 78, 79]
# [[['ford pinto', 75, 2769], ['toyota corolla', 75, 2711]], [['ford pinto', 76, 3025]], [['toyota corolla', 77, 2789], ['toyota highlander', 77, 2789]], [['toyota toy', 78, 13]], [['toyota corolla', 79, 3453]]]

# %%
np.random.seed(0)
values = np.random.choice(100,20)
values = sorted(list(values))
print(values)
plt_freq,plt_cutoffs,plt_artists = plt.hist(values, bins=5,edgecolor="black")
# Out:
# [9, 12, 21, 36, 39, 44, 46, 47, 58, 64, 65, 67, 67, 70, 83, 87, 87, 88, 88, 88]

# %%
import importlib
importlib.reload(utils)

cutoffs = utils.comput_equal_width_cutoffs(values,5)
print(cutoffs)
assert np.allclose(cutoffs, plt_cutoffs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/HelloWorldPersonalGH/MatplotlibExamples.ipynb Cell 17 in <cell line: 4>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f616e61222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/HelloWorldPersonalGH/MatplotlibExamples.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import importlib
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f616e61222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/HelloWorldPersonalGH/MatplotlibExamples.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> importlib.reload(utils)
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f616e61222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/HelloWorldPersonalGH/MatplotlibExamples.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> cutoffs = utils.comput_equal_width_cutoffs(values,5)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f616e61222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/HelloWorldPersonalGH/MatplotlibExamples.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(cutoffs)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f616e61222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/home/HelloWorldPersonalGH/MatplotlibExamples.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> assert np.allclose(cutoffs, plt_cutoffs)
#
# File /home/HelloWorldPersonalGH/utils.py:49, in comput_equal_width_cutoffs(values, num_bins)
#      47 values_range = max(values) - min(values)
#      48 bin_width = values_range/num_bins
# ---> 49 cutoffs = list(np.arrange(min(values),max(values), bin_width))
#      50 cutoffs.append(max(values))
#      51 cutoffs = [round(cutoff,2) for cutoff in cutoffs]
#
# File /opt/conda/lib/python3.9/site-packages/numpy/__init__.py:313, in __getattr__(attr)
#     310     from .testing import Tester
#     311     return Tester
# --> 313 raise AttributeError("module {!r} has no attribute "
#     314                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %% [markdown]
# ### Linear Regression
# * Suppose we have some x and y data
#     * x is an independent variable
#     * y is a dependent variable
# * Recall: $y = mx + b$
# * If we are interested in seeing if there is a linera relationship
# between x and y, then we can fit a line to the data
# * we will use a simple approcach called "east squares" for univariate data (one independent variable)
#     * The fit line must pass through ($\overline{x}$,$\overline{y}$)
#     * We can compute $m$ using a known formula (U3/Linear Regression)
#     * We can then solve for $b$

# %%
import numpy as np
from scipy import stats
import importlib
importlib.reload(utils)
np.random.seed(0)
x = list(range(0,100))
y = [value * 2 + np.random.normal(0,25) for value in x]

plt.scatter(x,y)

#calculate m and b from this x,y data
m,b = utils.compute_slope_intercept(x,y)
print(m,b)
# test against scipy
sp_m,sp_b,sp_r,sp_rval,sp_std_err = stats.linregress(x,y)
assert np.isclose(m,sp_m)
assert np.isclose(b,sp_b)

plt.plot([min(x), max(x)],[m*min(x)+b, m*max(x)+b], c="darkgreen")
# Out:
# 1.924917458430444 5.211786196055144

# %% [markdown]
# ### Quantifying the strength of a linear relationship
# * Some Metrics
#     * Covariance
#     * Correlation
#     * Coefficient of Determination
#     * Standard Error
#     * Mean Absolute Error (MAE)
#     * Root Mean Squared Error (RMSE)
#     * Others...
# * Focus on correlation $r$
#     * $r$ is in '[-1.0,1.0]'
#     * 1.0 represents a perfect linear relationship(s xx increase, so does y)
#     * -1.0 represenets a perfect inverse linear relationship ( as x increase, y decreases)
#     * 0.0 represents no linear relationship
# * Note: correlation does not imply causation

# %%
print("correlation(r):",sp_r)
# Out:
# correlation(r): 0.9113097511932392
